# %%
# Written by W.T. Chung

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import tensorflow as tf
import matplotlib.pyplot as plt
import os

# %%
tf.keras.utils.set_random_seed(812)

# This will make TensorFlow ops as deterministic as possible, but it will
# affect the overall performance, so it's not enabled by default.
# `enable_op_determinism()` is introduced in TensorFlow 2.9.
tf.config.experimental.enable_op_determinism()

input_path = './dataset/'

# %%
#taken from keras tutorial: https://keras.io/examples/vision/edsr/
from tensorflow.keras import layers
from tensorflow.keras.models import Model


# Residual Block

def ResBlock(inputs):
    x = layers.Conv2D(64, 3, padding="same", activation="relu")(inputs)
    x = layers.Conv2D(64, 3, padding="same")(x)
    x = layers.Add()([inputs, x])
    return x


# Upsampling Block
def Upsampling(inputs, factor=2, **kwargs):
    x = layers.Conv2D(64 * (factor ** 2), 3, padding="same", **kwargs)(inputs)
    x = tf.nn.depth_to_space(x, block_size=factor)
    x = layers.Conv2D(64 * (factor ** 2), 3, padding="same", **kwargs)(x)
    x = tf.nn.depth_to_space(x, block_size=factor)
    x = layers.Conv2D(64 * (factor ** 2), 3, padding="same", **kwargs)(x)
    x = tf.nn.depth_to_space(x, block_size=factor)
    return x


def make_model(num_filters=64, num_of_residual_blocks=16):
    # Flexible Inputs to input_layer
    input_layer = layers.Input(shape=(None, None, 1))
    # Scaling Pixel Values
    x = x_new = layers.Conv2D(num_filters, 3, padding="same")(input_layer)

    # 16 residual blocks
    for _ in range(num_of_residual_blocks):
        x_new = ResBlock(x_new)

    x_new = layers.Conv2D(num_filters, 3, padding="same")(x_new)
    x = layers.Add()([x, x_new])

    x = Upsampling(x)
    output_layer = layers.Conv2D(1, 3, padding="same")(x)

    return Model(input_layer, output_layer)

model = make_model()
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, None, None, 1)]      0         []
#
#  conv2d (Conv2D)             (None, None, None, 64)       640       ['input_1[0][0]']
#
#  conv2d_1 (Conv2D)           (None, None, None, 64)       36928     ['conv2d[0][0]']
#
#  conv2d_2 (Conv2D)           (None, None, None, 64)       36928     ['conv2d_1[0][0]']
#
#  add (Add)                   (None, None, None, 64)       0         ['conv2d[0][0]',
#                                                                      'conv2d_2[0][0]']
#
#  conv2d_3 (Conv2D)           (None, None, None, 64)       36928     ['add[0][0]']
#
#  conv2d_4 (Conv2D)           (None, None, None, 64)       36928     ['conv2d_3[0][0]']
#
#  add_1 (Add)                 (None, None, None, 64)       0         ['add[0][0]',
#                                                                      'conv2d_4[0][0]']
#
#  conv2d_5 (Conv2D)           (None, None, None, 64)       36928     ['add_1[0][0]']
#
#  conv2d_6 (Conv2D)           (None, None, None, 64)       36928     ['conv2d_5[0][0]']
#
#  add_2 (Add)                 (None, None, None, 64)       0         ['add_1[0][0]',
#                                                                      'conv2d_6[0][0]']
#
#  conv2d_7 (Conv2D)           (None, None, None, 64)       36928     ['add_2[0][0]']
#
#  conv2d_8 (Conv2D)           (None, None, None, 64)       36928     ['conv2d_7[0][0]']
#
#  add_3 (Add)                 (None, None, None, 64)       0         ['add_2[0][0]',
#                                                                      'conv2d_8[0][0]']
#
#  conv2d_9 (Conv2D)           (None, None, None, 64)       36928     ['add_3[0][0]']
#
#  conv2d_10 (Conv2D)          (None, None, None, 64)       36928     ['conv2d_9[0][0]']
#
#  add_4 (Add)                 (None, None, None, 64)       0         ['add_3[0][0]',
#                                                                      'conv2d_10[0][0]']
#
#  conv2d_11 (Conv2D)          (None, None, None, 64)       36928     ['add_4[0][0]']
#
#  conv2d_12 (Conv2D)          (None, None, None, 64)       36928     ['conv2d_11[0][0]']
#
#  add_5 (Add)                 (None, None, None, 64)       0         ['add_4[0][0]',
#                                                                      'conv2d_12[0][0]']
#
#  conv2d_13 (Conv2D)          (None, None, None, 64)       36928     ['add_5[0][0]']
#
#  conv2d_14 (Conv2D)          (None, None, None, 64)       36928     ['conv2d_13[0][0]']
#
#  add_6 (Add)                 (None, None, None, 64)       0         ['add_5[0][0]',
#                                                                      'conv2d_14[0][0]']
#
#  conv2d_15 (Conv2D)          (None, None, None, 64)       36928     ['add_6[0][0]']
#
#  conv2d_16 (Conv2D)          (None, None, None, 64)       36928     ['conv2d_15[0][0]']
#
#  add_7 (Add)                 (None, None, None, 64)       0         ['add_6[0][0]',
#                                                                      'conv2d_16[0][0]']
#
#  conv2d_17 (Conv2D)          (None, None, None, 64)       36928     ['add_7[0][0]']
#
#  conv2d_18 (Conv2D)          (None, None, None, 64)       36928     ['conv2d_17[0][0]']
#
#  add_8 (Add)                 (None, None, None, 64)       0         ['add_7[0][0]',
#                                                                      'conv2d_18[0][0]']
#
#  conv2d_19 (Conv2D)          (None, None, None, 64)       36928     ['add_8[0][0]']
#
#  conv2d_20 (Conv2D)          (None, None, None, 64)       36928     ['conv2d_19[0][0]']
#
#  add_9 (Add)                 (None, None, None, 64)       0         ['add_8[0][0]',
#                                                                      'conv2d_20[0][0]']
#
#  conv2d_21 (Conv2D)          (None, None, None, 64)       36928     ['add_9[0][0]']
#
#  conv2d_22 (Conv2D)          (None, None, None, 64)       36928     ['conv2d_21[0][0]']
#
#  add_10 (Add)                (None, None, None, 64)       0         ['add_9[0][0]',
#                                                                      'conv2d_22[0][0]']
#
#  conv2d_23 (Conv2D)          (None, None, None, 64)       36928     ['add_10[0][0]']
#
#  conv2d_24 (Conv2D)          (None, None, None, 64)       36928     ['conv2d_23[0][0]']
#
#  add_11 (Add)                (None, None, None, 64)       0         ['add_10[0][0]',
#                                                                      'conv2d_24[0][0]']
#
#  conv2d_25 (Conv2D)          (None, None, None, 64)       36928     ['add_11[0][0]']
#
#  conv2d_26 (Conv2D)          (None, None, None, 64)       36928     ['conv2d_25[0][0]']
#
#  add_12 (Add)                (None, None, None, 64)       0         ['add_11[0][0]',
#                                                                      'conv2d_26[0][0]']
#
#  conv2d_27 (Conv2D)          (None, None, None, 64)       36928     ['add_12[0][0]']
#
#  conv2d_28 (Conv2D)          (None, None, None, 64)       36928     ['conv2d_27[0][0]']
#
#  add_13 (Add)                (None, None, None, 64)       0         ['add_12[0][0]',
#                                                                      'conv2d_28[0][0]']
#
#  conv2d_29 (Conv2D)          (None, None, None, 64)       36928     ['add_13[0][0]']
#
#  conv2d_30 (Conv2D)          (None, None, None, 64)       36928     ['conv2d_29[0][0]']
#
#  add_14 (Add)                (None, None, None, 64)       0         ['add_13[0][0]',
#                                                                      'conv2d_30[0][0]']
#
#  conv2d_31 (Conv2D)          (None, None, None, 64)       36928     ['add_14[0][0]']
#
#  conv2d_32 (Conv2D)          (None, None, None, 64)       36928     ['conv2d_31[0][0]']
#
#  add_15 (Add)                (None, None, None, 64)       0         ['add_14[0][0]',
#                                                                      'conv2d_32[0][0]']
#
#  conv2d_33 (Conv2D)          (None, None, None, 64)       36928     ['add_15[0][0]']
#
#  add_16 (Add)                (None, None, None, 64)       0         ['conv2d[0][0]',
#                                                                      'conv2d_33[0][0]']
#
#  conv2d_34 (Conv2D)          (None, None, None, 256)      147712    ['add_16[0][0]']
#
#  tf.nn.depth_to_space (TFOp  (None, None, None, 64)       0         ['conv2d_34[0][0]']
#  Lambda)
#
#  conv2d_35 (Conv2D)          (None, None, None, 256)      147712    ['tf.nn.depth_to_space[0][0]']
#
#  tf.nn.depth_to_space_1 (TF  (None, None, None, 64)       0         ['conv2d_35[0][0]']
#  OpLambda)
#
#  conv2d_36 (Conv2D)          (None, None, None, 256)      147712    ['tf.nn.depth_to_space_1[0][0]
#                                                                     ']
#
#  tf.nn.depth_to_space_2 (TF  (None, None, None, 64)       0         ['conv2d_36[0][0]']
#  OpLambda)
#
#  conv2d_37 (Conv2D)          (None, None, None, 1)        577       ['tf.nn.depth_to_space_2[0][0]
#                                                                     ']
#
# ==================================================================================================
# Total params: 1662977 (6.34 MB)
# Trainable params: 1662977 (6.34 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
#get filenames
def getFiles(mode = "train",scalar = 'YOH'):
    HR_path = input_path + "HR/"+scalar+'/' + mode
    files = os.listdir(HR_path)
    train_files = []
    for idx,file in enumerate(files):
        if file.startswith('YOH'):
            train_files.append(file)
    for idx,file in enumerate(train_files):
        train_files[idx] = file[3:]
    return train_files

# %%
train_files = getFiles()
val_files =  getFiles('val')
test_files =  getFiles('test')

# %%
my_mean = 0.003057
my_std = 0.002693
def getXY(idx,filenames,mode = "train",scalar = 'YOH'):
    LR_path = input_path + "LR/"+scalar+'/' + mode
    HR_path = input_path + "HR/"+scalar+'/' + mode

    X = (np.fromfile(LR_path + "/"+scalar + filenames[idx], dtype="<f4").reshape(16,16,1) - my_mean)/my_std
    Y = (np.fromfile(HR_path + "/"+scalar + filenames[idx], dtype="<f4").reshape(128,128,1)- my_mean)/my_std
    X = tf.convert_to_tensor(X,dtype=tf.float32)
    Y = tf.convert_to_tensor(Y,dtype=tf.float32)
    return [X,Y]

def getTrainXY(idx):
    return getXY(idx,train_files,mode = "train")

def getValXY(idx):
    return getXY(idx,val_files,mode = "val")
def getTestXY(idx):
    return getXY(idx,val_files,mode = "test")

# %%
X0,Y0 = getXY(0,train_files,mode = "train")
print("Feature shapes:")
print( X0.shape)
print("Label shapes:")
print( Y0.shape)

nx_in, ny_in, nc_in = X0.shape
nx_out, ny_out, nc_out = Y0.shape
# Out:
# Feature shapes:
# (16, 16, 1)
# Label shapes:
# (128, 128, 1)

# %%
def load_train_dataset_wrapper(file_idx):
    return tf.py_function(getTrainXY, inp=[file_idx], Tout=[tf.float32,tf.float32])

def load_val_dataset_wrapper(file_idx):
    return tf.py_function(getValXY, inp=[file_idx], Tout=[tf.float32,tf.float32])

batch_size = 32 #divisible by number of gpus
nfile = len(train_files)
train_ds = tf.data.Dataset.from_tensor_slices(range(nfile))
train_ds = (train_ds
    .shuffle(nfile)
    .map(load_train_dataset_wrapper, num_parallel_calls=tf.data.AUTOTUNE)
#     .map(scale_wrapper, num_parallel_calls=tf.data.AUTOTUNE)
    .batch(batch_size)
    .prefetch(tf.data.AUTOTUNE)
)

nfile = len(val_files)
val_ds = tf.data.Dataset.from_tensor_slices(range(nfile))
val_ds = (val_ds
    .map(load_val_dataset_wrapper, num_parallel_calls=tf.data.AUTOTUNE)
#     .map(scale_wrapper, num_parallel_calls=tf.data.AUTOTUNE)
    .batch(batch_size)
    .prefetch(tf.data.AUTOTUNE)
)

# %%
#create directories for checkpoints and logs
log_dir = "./logs"
checkpoint_dir = "./ckpt"
if not os.path.exists(checkpoint_dir):
    os.makedirs(checkpoint_dir)
if not os.path.exists(log_dir):
    os.makedirs(log_dir)

# Either restore the latest model, or create a fresh one if there is no checkpoint available.
def make_or_restore_model(alpha=1e-3,checkpoint_dir=checkpoint_dir,ckpt=None):
    model =  make_model()
    #set up save/load checkpoints
    if ckpt:
      latest_checkpoint = checkpoint_dir + "/ckpt-" +str(ckpt)
      print("Restoring from", latest_checkpoint)
      nckpt = int(latest_checkpoint.split('-')[-1])
      restored_model =  tf.keras.models.load_model(latest_checkpoint)
      model.set_weights(restored_model.get_weights())
    else:
      checkpoints = [checkpoint_dir + "/" + name for name in os.listdir(checkpoint_dir)]
      nckpt = 0
      if checkpoints:
          latest_checkpoint = max(checkpoints, key=os.path.getctime)
          print("Restoring from", latest_checkpoint)
          nckpt = int(latest_checkpoint.split('-')[-1])
          restored_model =  tf.keras.models.load_model(latest_checkpoint)
          model.set_weights(restored_model.get_weights())
      else:
          print("Creating a new model")

    #compile model with optimizerloss functions,metrics
    #NOTE: Although we're only using MSE as the public metric here, we will be also evaluating with SSIM-based metrics to search for best models so you may want to monitor other metrics
    model.compile(optimizer = tf.keras.optimizers.Adam(learning_rate=alpha),
        loss=tf.keras.losses.MeanSquaredError(reduction='sum_over_batch_size'),
           metrics =[tf.keras.metrics.MeanAbsoluteError()]) #add other metrics here

    return [model,nckpt]

# %%
def run_training(train_dataset=train_ds,val_dataset=val_ds,epochs=100,lr=1e-3,ckpt=None,checkpoint_dir=checkpoint_dir,log_dir=log_dir):
    # Create a MirroredStrategy for multi-gpu
    strategy = tf.distribute.MirroredStrategy()
    print('Number of GPUs: {}'.format(strategy.num_replicas_in_sync))

    # For multi-gpu: Open a strategy scope and create/restore the model
    with strategy.scope():
        [model,nckpt] = make_or_restore_model(alpha=lr,ckpt=ckpt,checkpoint_dir=checkpoint_dir)
    #set up checkpoints and logs
    callbacks = [
        # This callback saves a SavedModel every epoch
        tf.keras.callbacks.ModelCheckpoint(
            filepath=checkpoint_dir + "/ckpt-{epoch}", save_freq="epoch"
        ),
        # This callback logs every epoch
        tf.keras.callbacks.CSVLogger(log_dir + "/model_history_log.csv", append=True)
    ]

    #train
    model.fit(
        train_dataset,
        epochs=epochs,
        initial_epoch=nckpt,
        callbacks=callbacks,
        verbose=1,
        validation_data = val_dataset
    )

    #save at the end of epoch
    model.save('./final_model')

    
def finetune(train_ds=train_ds,val_dataset=val_ds,epochs=150,lr=1e-5,ckpt=None,checkpoint_dir=checkpoint_dir,log_dir=log_dir):
    run_training(train_dataset=train_ds,val_dataset=val_ds,epochs=epochs,lr=lr,ckpt=ckpt,checkpoint_dir=checkpoint_dir,log_dir=log_dir)

# %%
finetune(epochs=193,lr=1e-4)
# Out:
# Number of GPUs: 1
# Restoring from /content/drive/My Drive/pci_invited/ckptPretrainedV2/ckpt-92
# Epoch 93/193
# 1/1 [==============================] - 19s 19s/step - loss: 0.1008 - mean_absolute_error: 0.1948 - val_loss: 0.0482 - val_mean_absolute_error: 0.1568
# Epoch 94/193
# 1/1 [==============================] - 7s 7s/step - loss: 0.0625 - mean_absolute_error: 0.1773 - val_loss: 0.0334 - val_mean_absolute_error: 0.1287
# Epoch 95/193
# 1/1 [==============================] - 7s 7s/step - loss: 0.0429 - mean_absolute_error: 0.1425 - val_loss: 0.0322 - val_mean_absolute_error: 0.1305
# Epoch 96/193
# 1/1 [==============================] - 8s 8s/step - loss: 0.0408 - mean_absolute_error: 0.1457 - val_loss: 0.0305 - val_mean_absolute_error: 0.1248
# Epoch 97/193
# 1/1 [==============================] - 7s 7s/step - loss: 0.0375 - mean_absolute_error: 0.1353 - val_loss: 0.0274 - val_mean_absolute_error: 0.1157
# Epoch 98/193
# 1/1 [==============================] - 6s 6s/step - loss: 0.0332 - mean_absolute_error: 0.1245 - val_loss: 0.0262 - val_mean_absolute_error: 0.1145
# Epoch 99/193
# 1/1 [==============================] - 7s 7s/step - loss: 0.0310 - mean_absolute_error: 0.1225 - val_loss: 0.0238 - val_mean_absolute_error: 0.1090
# Epoch 100/193
# 1/1 [==============================] - 6s 6s/step - loss: 0.0285 - mean_absolute_error: 0.1179 - val_loss: 0.0232 - val_mean_absolute_error: 0.1074
# Epoch 101/193
# 1/1 [==============================] - 7s 7s/step - loss: 0.0280 - mean_absolute_error: 0.1168 - val_loss: 0.0227 - val_mean_absolute_error: 0.1057
# Epoch 102/193
# 1/1 [==============================] - 6s 6s/step - loss: 0.0269 - mean_absolute_error: 0.1143 - val_loss: 0.0218 - val_mean_absolute_error: 0.1032
# Epoch 103/193
# 1/1 [==============================] - 7s 7s/step - loss: 0.0252 - mean_absolute_error: 0.1102 - val_loss: 0.0211 - val_mean_absolute_error: 0.1013
# Epoch 104/193
# 1/1 [==============================] - 6s 6s/step - loss: 0.0240 - mean_absolute_error: 0.1074 - val_loss: 0.0200 - val_mean_absolute_error: 0.0973
# Epoch 105/193
# 1/1 [==============================] - 7s 7s/step - loss: 0.0228 - mean_absolute_error: 0.1040 - val_loss: 0.0190 - val_mean_absolute_error: 0.0943
# Epoch 106/193
# 1/1 [==============================] - 6s 6s/step - loss: 0.0219 - mean_absolute_error: 0.1011 - val_loss: 0.0187 - val_mean_absolute_error: 0.0936
# Epoch 107/193
# 1/1 [==============================] - 6s 6s/step - loss: 0.0215 - mean_absolute_error: 0.1006 - val_loss: 0.0184 - val_mean_absolute_error: 0.0927
# Epoch 108/193
# 1/1 [==============================] - 7s 7s/step - loss: 0.0210 - mean_absolute_error: 0.0999 - val_loss: 0.0180 - val_mean_absolute_error: 0.0911
# Epoch 109/193
# 1/1 [==============================] - 6s 6s/step - loss: 0.0204 - mean_absolute_error: 0.0974 - val_loss: 0.0178 - val_mean_absolute_error: 0.0908
# Epoch 110/193
# 1/1 [==============================] - 7s 7s/step - loss: 0.0200 - mean_absolute_error: 0.0966 - val_loss: 0.0175 - val_mean_absolute_error: 0.0900
# Epoch 111/193
# 1/1 [==============================] - 6s 6s/step - loss: 0.0195 - mean_absolute_error: 0.0955 - val_loss: 0.0171 - val_mean_absolute_error: 0.0883
# Epoch 112/193
# 1/1 [==============================] - 7s 7s/step - loss: 0.0189 - mean_absolute_error: 0.0933 - val_loss: 0.0170 - val_mean_absolute_error: 0.0878
# Epoch 113/193
# 1/1 [==============================] - 6s 6s/step - loss: 0.0186 - mean_absolute_error: 0.0925 - val_loss: 0.0168 - val_mean_absolute_error: 0.0872
# Epoch 114/193
# 1/1 [==============================] - 7s 7s/step - loss: 0.0181 - mean_absolute_error: 0.0911 - val_loss: 0.0167 - val_mean_absolute_error: 0.0869
# Epoch 115/193
# 1/1 [==============================] - 6s 6s/step - loss: 0.0177 - mean_absolute_error: 0.0897 - val_loss: 0.0167 - val_mean_absolute_error: 0.0872
# Epoch 116/193
# 1/1 [==============================] - 6s 6s/step - loss: 0.0174 - mean_absolute_error: 0.0894 - val_loss: 0.0168 - val_mean_absolute_error: 0.0873
# Epoch 117/193
# 1/1 [==============================] - 8s 8s/step - loss: 0.0171 - mean_absolute_error: 0.0887 - val_loss: 0.0166 - val_mean_absolute_error: 0.0867
# Epoch 118/193
# 1/1 [==============================] - 7s 7s/step - loss: 0.0168 - mean_absolute_error: 0.0875 - val_loss: 0.0165 - val_mean_absolute_error: 0.0860
# Epoch 119/193
# 1/1 [==============================] - 6s 6s/step - loss: 0.0164 - mean_absolute_error: 0.0863 - val_loss: 0.0164 - val_mean_absolute_error: 0.0856
# Epoch 120/193
# 1/1 [==============================] - 6s 6s/step - loss: 0.0162 - mean_absolute_error: 0.0854 - val_loss: 0.0163 - val_mean_absolute_error: 0.0851
# Epoch 121/193
# 1/1 [==============================] - 6s 6s/step - loss: 0.0159 - mean_absolute_error: 0.0844 - val_loss: 0.0163 - val_mean_absolute_error: 0.0850
# Epoch 122/193
# 1/1 [==============================] - 7s 7s/step - loss: 0.0156 - mean_absolute_error: 0.0836 - val_loss: 0.0163 - val_mean_absolute_error: 0.0851
# Epoch 123/193
# 1/1 [==============================] - 6s 6s/step - loss: 0.0154 - mean_absolute_error: 0.0832 - val_loss: 0.0162 - val_mean_absolute_error: 0.0847
# Epoch 124/193
# 1/1 [==============================] - 6s 6s/step - loss: 0.0151 - mean_absolute_error: 0.0824 - val_loss: 0.0160 - val_mean_absolute_error: 0.0842
# Epoch 125/193
# 1/1 [==============================] - 6s 6s/step - loss: 0.0149 - mean_absolute_error: 0.0815 - val_loss: 0.0160 - val_mean_absolute_error: 0.0840
# Epoch 126/193
# 1/1 [==============================] - 7s 7s/step - loss: 0.0147 - mean_absolute_error: 0.0809 - val_loss: 0.0159 - val_mean_absolute_error: 0.0840
# Epoch 127/193
# 1/1 [==============================] - 6s 6s/step - loss: 0.0144 - mean_absolute_error: 0.0805 - val_loss: 0.0159 - val_mean_absolute_error: 0.0838
# Epoch 128/193
# 1/1 [==============================] - 7s 7s/step - loss: 0.0142 - mean_absolute_error: 0.0796 - val_loss: 0.0159 - val_mean_absolute_error: 0.0836
# Epoch 129/193
# 1/1 [==============================] - 6s 6s/step - loss: 0.0140 - mean_absolute_error: 0.0790 - val_loss: 0.0158 - val_mean_absolute_error: 0.0835
# Epoch 130/193
# 1/1 [==============================] - 7s 7s/step - loss: 0.0138 - mean_absolute_error: 0.0785 - val_loss: 0.0158 - val_mean_absolute_error: 0.0831
# Epoch 131/193
# 1/1 [==============================] - 6s 6s/step - loss: 0.0136 - mean_absolute_error: 0.0776 - val_loss: 0.0157 - val_mean_absolute_error: 0.0828
# Epoch 132/193
# 1/1 [==============================] - 7s 7s/step - loss: 0.0134 - mean_absolute_error: 0.0770 - val_loss: 0.0157 - val_mean_absolute_error: 0.0825
# Epoch 133/193
# 1/1 [==============================] - 6s 6s/step - loss: 0.0133 - mean_absolute_error: 0.0764 - val_loss: 0.0157 - val_mean_absolute_error: 0.0824
# Epoch 134/193
# 1/1 [==============================] - 7s 7s/step - loss: 0.0131 - mean_absolute_error: 0.0758 - val_loss: 0.0156 - val_mean_absolute_error: 0.0824
# Epoch 135/193
# 1/1 [==============================] - 6s 6s/step - loss: 0.0129 - mean_absolute_error: 0.0754 - val_loss: 0.0157 - val_mean_absolute_error: 0.0825
# Epoch 136/193
# 1/1 [==============================] - 7s 7s/step - loss: 0.0127 - mean_absolute_error: 0.0750 - val_loss: 0.0156 - val_mean_absolute_error: 0.0824
# Epoch 137/193
# 1/1 [==============================] - 6s 6s/step - loss: 0.0126 - mean_absolute_error: 0.0745 - val_loss: 0.0156 - val_mean_absolute_error: 0.0824
# Epoch 138/193
# 1/1 [==============================] - 7s 7s/step - loss: 0.0124 - mean_absolute_error: 0.0741 - val_loss: 0.0156 - val_mean_absolute_error: 0.0824
# Epoch 139/193
# 1/1 [==============================] - 6s 6s/step - loss: 0.0123 - mean_absolute_error: 0.0736 - val_loss: 0.0156 - val_mean_absolute_error: 0.0825
# Epoch 140/193
# 1/1 [==============================] - 7s 7s/step - loss: 0.0121 - mean_absolute_error: 0.0731 - val_loss: 0.0156 - val_mean_absolute_error: 0.0826
# Epoch 141/193
# 1/1 [==============================] - 7s 7s/step - loss: 0.0119 - mean_absolute_error: 0.0726 - val_loss: 0.0156 - val_mean_absolute_error: 0.0826
# Epoch 142/193
# 1/1 [==============================] - 6s 6s/step - loss: 0.0118 - mean_absolute_error: 0.0721 - val_loss: 0.0156 - val_mean_absolute_error: 0.0825
# Epoch 143/193
# 1/1 [==============================] - 7s 7s/step - loss: 0.0116 - mean_absolute_error: 0.0716 - val_loss: 0.0156 - val_mean_absolute_error: 0.0825
# Epoch 144/193
# 1/1 [==============================] - 6s 6s/step - loss: 0.0115 - mean_absolute_error: 0.0711 - val_loss: 0.0156 - val_mean_absolute_error: 0.0826
# Epoch 145/193
# 1/1 [==============================] - 7s 7s/step - loss: 0.0113 - mean_absolute_error: 0.0707 - val_loss: 0.0157 - val_mean_absolute_error: 0.0826
# Epoch 146/193
# 1/1 [==============================] - 6s 6s/step - loss: 0.0112 - mean_absolute_error: 0.0702 - val_loss: 0.0157 - val_mean_absolute_error: 0.0827
# Epoch 147/193
# 1/1 [==============================] - 7s 7s/step - loss: 0.0110 - mean_absolute_error: 0.0698 - val_loss: 0.0157 - val_mean_absolute_error: 0.0828
# Epoch 148/193
# 1/1 [==============================] - 6s 6s/step - loss: 0.0109 - mean_absolute_error: 0.0694 - val_loss: 0.0157 - val_mean_absolute_error: 0.0828
# Epoch 149/193
# 1/1 [==============================] - 7s 7s/step - loss: 0.0107 - mean_absolute_error: 0.0689 - val_loss: 0.0157 - val_mean_absolute_error: 0.0828
# Epoch 150/193
# 1/1 [==============================] - 6s 6s/step - loss: 0.0106 - mean_absolute_error: 0.0684 - val_loss: 0.0157 - val_mean_absolute_error: 0.0828
# Epoch 151/193
# 1/1 [==============================] - 7s 7s/step - loss: 0.0104 - mean_absolute_error: 0.0680 - val_loss: 0.0157 - val_mean_absolute_error: 0.0828
# Epoch 152/193
# 1/1 [==============================] - 6s 6s/step - loss: 0.0103 - mean_absolute_error: 0.0675 - val_loss: 0.0158 - val_mean_absolute_error: 0.0829
# Epoch 153/193
# 1/1 [==============================] - 7s 7s/step - loss: 0.0101 - mean_absolute_error: 0.0671 - val_loss: 0.0158 - val_mean_absolute_error: 0.0830
# Epoch 154/193
# 1/1 [==============================] - 6s 6s/step - loss: 0.0100 - mean_absolute_error: 0.0666 - val_loss: 0.0158 - val_mean_absolute_error: 0.0830
# Epoch 155/193
# 1/1 [==============================] - 6s 6s/step - loss: 0.0098 - mean_absolute_error: 0.0662 - val_loss: 0.0158 - val_mean_absolute_error: 0.0831
# Epoch 156/193
# 1/1 [==============================] - 6s 6s/step - loss: 0.0097 - mean_absolute_error: 0.0658 - val_loss: 0.0158 - val_mean_absolute_error: 0.0833
# Epoch 157/193
# 1/1 [==============================] - 7s 7s/step - loss: 0.0096 - mean_absolute_error: 0.0654 - val_loss: 0.0159 - val_mean_absolute_error: 0.0834
# Epoch 158/193
# 1/1 [==============================] - 6s 6s/step - loss: 0.0094 - mean_absolute_error: 0.0649 - val_loss: 0.0159 - val_mean_absolute_error: 0.0835
# Epoch 159/193
# 1/1 [==============================] - 7s 7s/step - loss: 0.0093 - mean_absolute_error: 0.0645 - val_loss: 0.0159 - val_mean_absolute_error: 0.0835
# Epoch 160/193
# 1/1 [==============================] - 6s 6s/step - loss: 0.0092 - mean_absolute_error: 0.0641 - val_loss: 0.0159 - val_mean_absolute_error: 0.0836
# Epoch 161/193
# 1/1 [==============================] - 6s 6s/step - loss: 0.0090 - mean_absolute_error: 0.0637 - val_loss: 0.0159 - val_mean_absolute_error: 0.0837
# Epoch 162/193
# 1/1 [==============================] - 7s 7s/step - loss: 0.0089 - mean_absolute_error: 0.0632 - val_loss: 0.0160 - val_mean_absolute_error: 0.0838
# Epoch 163/193
# 1/1 [==============================] - 6s 6s/step - loss: 0.0088 - mean_absolute_error: 0.0628 - val_loss: 0.0160 - val_mean_absolute_error: 0.0839
# Epoch 164/193
# 1/1 [==============================] - 8s 8s/step - loss: 0.0087 - mean_absolute_error: 0.0624 - val_loss: 0.0160 - val_mean_absolute_error: 0.0840
# Epoch 165/193
# 1/1 [==============================] - 7s 7s/step - loss: 0.0085 - mean_absolute_error: 0.0620 - val_loss: 0.0161 - val_mean_absolute_error: 0.0840
# Epoch 166/193
# 1/1 [==============================] - 6s 6s/step - loss: 0.0084 - mean_absolute_error: 0.0616 - val_loss: 0.0161 - val_mean_absolute_error: 0.0841
# Epoch 167/193
# 1/1 [==============================] - 6s 6s/step - loss: 0.0083 - mean_absolute_error: 0.0612 - val_loss: 0.0161 - val_mean_absolute_error: 0.0842
# Epoch 168/193
# 1/1 [==============================] - 6s 6s/step - loss: 0.0082 - mean_absolute_error: 0.0608 - val_loss: 0.0161 - val_mean_absolute_error: 0.0843
# Epoch 169/193
# 1/1 [==============================] - 7s 7s/step - loss: 0.0081 - mean_absolute_error: 0.0604 - val_loss: 0.0162 - val_mean_absolute_error: 0.0844
# Epoch 170/193
# 1/1 [==============================] - 6s 6s/step - loss: 0.0079 - mean_absolute_error: 0.0600 - val_loss: 0.0162 - val_mean_absolute_error: 0.0845
# Epoch 171/193
# 1/1 [==============================] - 7s 7s/step - loss: 0.0078 - mean_absolute_error: 0.0596 - val_loss: 0.0162 - val_mean_absolute_error: 0.0845
# Epoch 172/193
# 1/1 [==============================] - 6s 6s/step - loss: 0.0077 - mean_absolute_error: 0.0592 - val_loss: 0.0162 - val_mean_absolute_error: 0.0846
# Epoch 173/193
# 1/1 [==============================] - 7s 7s/step - loss: 0.0076 - mean_absolute_error: 0.0588 - val_loss: 0.0162 - val_mean_absolute_error: 0.0847
# Epoch 174/193
# 1/1 [==============================] - 6s 6s/step - loss: 0.0075 - mean_absolute_error: 0.0584 - val_loss: 0.0163 - val_mean_absolute_error: 0.0848
# Epoch 175/193
# 1/1 [==============================] - 7s 7s/step - loss: 0.0074 - mean_absolute_error: 0.0580 - val_loss: 0.0163 - val_mean_absolute_error: 0.0849
# Epoch 176/193
# 1/1 [==============================] - 6s 6s/step - loss: 0.0073 - mean_absolute_error: 0.0576 - val_loss: 0.0163 - val_mean_absolute_error: 0.0850
# Epoch 177/193
# 1/1 [==============================] - 7s 7s/step - loss: 0.0072 - mean_absolute_error: 0.0573 - val_loss: 0.0164 - val_mean_absolute_error: 0.0851
# Epoch 178/193
# 1/1 [==============================] - 6s 6s/step - loss: 0.0071 - mean_absolute_error: 0.0569 - val_loss: 0.0164 - val_mean_absolute_error: 0.0852
# Epoch 179/193
# 1/1 [==============================] - 7s 7s/step - loss: 0.0070 - mean_absolute_error: 0.0565 - val_loss: 0.0164 - val_mean_absolute_error: 0.0853
# Epoch 180/193
# 1/1 [==============================] - 6s 6s/step - loss: 0.0069 - mean_absolute_error: 0.0562 - val_loss: 0.0164 - val_mean_absolute_error: 0.0854
# Epoch 181/193
# 1/1 [==============================] - 7s 7s/step - loss: 0.0068 - mean_absolute_error: 0.0558 - val_loss: 0.0165 - val_mean_absolute_error: 0.0855
# Epoch 182/193
# 1/1 [==============================] - 6s 6s/step - loss: 0.0067 - mean_absolute_error: 0.0555 - val_loss: 0.0165 - val_mean_absolute_error: 0.0855
# Epoch 183/193
# 1/1 [==============================] - 7s 7s/step - loss: 0.0066 - mean_absolute_error: 0.0551 - val_loss: 0.0165 - val_mean_absolute_error: 0.0856
# Epoch 184/193
# 1/1 [==============================] - 6s 6s/step - loss: 0.0065 - mean_absolute_error: 0.0548 - val_loss: 0.0165 - val_mean_absolute_error: 0.0857
# Epoch 185/193
# 1/1 [==============================] - 7s 7s/step - loss: 0.0064 - mean_absolute_error: 0.0544 - val_loss: 0.0165 - val_mean_absolute_error: 0.0858
# Epoch 186/193
# 1/1 [==============================] - 6s 6s/step - loss: 0.0064 - mean_absolute_error: 0.0541 - val_loss: 0.0166 - val_mean_absolute_error: 0.0858
# Epoch 187/193
# 1/1 [==============================] - 7s 7s/step - loss: 0.0063 - mean_absolute_error: 0.0537 - val_loss: 0.0166 - val_mean_absolute_error: 0.0859
# Epoch 188/193
# 1/1 [==============================] - 7s 7s/step - loss: 0.0062 - mean_absolute_error: 0.0534 - val_loss: 0.0166 - val_mean_absolute_error: 0.0860
# Epoch 189/193
# 1/1 [==============================] - 7s 7s/step - loss: 0.0061 - mean_absolute_error: 0.0531 - val_loss: 0.0166 - val_mean_absolute_error: 0.0861
# Epoch 190/193
# 1/1 [==============================] - 6s 6s/step - loss: 0.0060 - mean_absolute_error: 0.0527 - val_loss: 0.0167 - val_mean_absolute_error: 0.0862
# Epoch 191/193
# 1/1 [==============================] - 7s 7s/step - loss: 0.0059 - mean_absolute_error: 0.0524 - val_loss: 0.0167 - val_mean_absolute_error: 0.0863
# Epoch 192/193
# 1/1 [==============================] - 6s 6s/step - loss: 0.0059 - mean_absolute_error: 0.0521 - val_loss: 0.0167 - val_mean_absolute_error: 0.0863
# Epoch 193/193
# 1/1 [==============================] - 7s 7s/step - loss: 0.0058 - mean_absolute_error: 0.0518 - val_loss: 0.0167 - val_mean_absolute_error: 0.0864

# %%
#if not exist mkdir
if not os.path.exists('./outputScratch'):
    os.makedirs('./outputScratch/'+checkpoint_dir)
    os.makedirs('./outputScratch/'+log_dir)

#train from scratch
run_training(epochs=250,ckpt=1,lr=1e-4,checkpoint_dir='./outputScratch/'+checkpoint_dir,log_dir='./outputScratch/'+log_dir)
